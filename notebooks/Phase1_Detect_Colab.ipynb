# %% [markdown]
# # Phase 1: WheelEye-Detect Training on Colab (T4 GPU)
#
# This notebook trains the custom single-stage detector on a Kaggle/Colab instance with a T4 GPU.

# %%
# !pip install torch torchvision numpy Pillow roboflow

# %% [markdown]
# ## 1. Clone the repository
# Clone the repository to bring the codebase into the Colab environment.

# %%
# !git clone https://github.com/GughanS/renault_nissan.git
# %cd renault_nissan

# %% [markdown]
# ## 2. Generate / Prepare Dataset
# For this portfolio project, we can generate a perfectly aligned **synthetic dataset** of geometric wheels, lug nuts, valve stems, and center caps to prove the training loop works end-to-end without manually labeling real photos yet.
#
# *Alternatively, you can use the commented-out Roboflow snippet to download a real dataset.*

# %%
# Generate 1000 synthetic images and labels in YOLO format
# !python scripts/generate_synthetic_data.py --num-images 1000 --out-dir ./data

# --- OPTIONAL: Real Data from Roboflow ---
# from roboflow import Roboflow
# rf = Roboflow(api_key="YOUR_API_KEY")
# project = rf.workspace("WORKSPACE_NAME").project("PROJECT_NAME")
# dataset = project.version(1).download("yolov8")

# %% [markdown]
# ## 3. Run Smoke Test
# Verify the implementation with a dummy data smoke test before running real training.

# %%
# !python tests/test_detector_smoke.py

# %% [markdown]
# ## 4. Train the Model
# This will run the training loop. We use `torch.cuda.amp` to optimize T4 memory usage and speed.
# It will train on the dataset located in `./data/images`.

# %%
# !python scripts/train_detect.py --img-dir ./data/images --label-dir ./data/labels --epochs 50 --batch-size 16
